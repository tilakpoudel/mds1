# %%
# k -nearest neighbors
# lazy learner - no training phase 
# classification algorithm
# non-parametric
# instance based learning
# lazy learner - no training phase

# %%
import seaborn as sns

# %%
# load dataset from seaborn
sns.get_dataset_names()

# can also load from scikit-learn
# from sklearn.datasets import load_iris
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
# load iris dataset
data = sns.load_dataset('iris')

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
data.shape
# Out:
# (150, 5)

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

# %%
x = data.drop('species', axis=1)

y = data['species']

# %%
print(x)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
# set the model
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(xtrain, ytrain)
# Out:
# KNeighborsClassifier()

# %%
# predict
knn.predict([[5.1, 3.5, 1.4, 0.2]])
# Out:
# /home/tilak/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array(['setosa'], dtype=object)

# %%
# predict the test set
ypred = knn.predict(xtest)

# %%
print(ypred)
# Out:
# ['virginica' 'versicolor' 'setosa' 'virginica' 'setosa' 'virginica'
#  'setosa' 'versicolor' 'versicolor' 'versicolor' 'virginica' 'versicolor'
#  'versicolor' 'versicolor' 'virginica' 'setosa' 'versicolor' 'versicolor'
#  'setosa' 'setosa' 'virginica' 'versicolor' 'setosa' 'setosa' 'virginica'
#  'setosa' 'setosa' 'versicolor' 'versicolor' 'setosa']

# %%
print(ytest)
# Out:
# 114     virginica
# 62     versicolor
# 33         setosa
# 107     virginica
# 7          setosa
# 100     virginica
# 40         setosa
# 86     versicolor
# 76     versicolor
# 71     versicolor
# 134     virginica
# 51     versicolor
# 73     versicolor
# 54     versicolor
# 63     versicolor
# 37         setosa
# 78     versicolor
# 90     versicolor
# 45         setosa
# 16         setosa
# 121     virginica
# 66     versicolor
# 24         setosa
# 8          setosa
# 126     virginica
# 22         setosa
# 44         setosa
# 97     versicolor
# 93     versicolor
# 26         setosa
# Name: species, dtype: object

# %%
# evaluate the model
cm = confusion_matrix(ytest, ypred)
print(cm)
# Out:
# [[11  0  0]
#  [ 0 12  1]
#  [ 0  0  6]]

# %%
# accuracy
print(accuracy_score(ytest, ypred))
# Out:
# 0.9666666666666667

# %%
# precision
print(precision_score(ytest, ypred, average='micro'))
# Out:
# 0.9666666666666667

# %%
# recall
print(recall_score(ytest, ypred, average='micro'))
# Out:
# 0.9666666666666667

# %%
# f1 score
print(f1_score(ytest, ypred, average='micro'))
# Out:
# 0.9666666666666667

# %% [markdown]
# Q.
